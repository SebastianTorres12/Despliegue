# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.svm import SVC
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, accuracy_score
import joblib

# %%
# Cargamos el dataset
file_path = 'data_evaluacion_decoded.csv'
df = pd.read_csv(file_path)

# Mostramos las primeras filas del dataset
df.head()
# Out:
#    Unnamed: 0  edad  fnlwgt  educacion  educacion_num  estado_civil  relacion  \
# 0           0    39   77516          9             13             1         1
# 1           1    50   83311          9             13             0         0
# 2           2    38  215646         11              9             1         1
# 3           3    53  234721          1              7             0         0
# 4           4    28  338409          9             13             0         5
#
#    ocupacion  raza  genero  ganancia-capital  perdida-capital  horas_semana  \
# 0          0     4       1                 1                0            40
# 1          3     4       1                 0                0            13
# 2          5     4       1                 0                0            40
# 3          5     2       1                 0                0            40
# 4          9     2       0                 0                0            40
#
#    pais  tipo_empleo  salario
# 0     1            0        1
# 1     1            2        1
# 2     1            1        1
# 3     1            1        1
# 4     0            1        1

# %%
x=df.drop(['salario'], axis=1)
x
# Out:
#        Unnamed: 0  edad  fnlwgt  educacion  educacion_num  estado_civil  \
# 0               0    39   77516          9             13             1
# 1               1    50   83311          9             13             0
# 2               2    38  215646         11              9             1
# 3               3    53  234721          1              7             0
# 4               4    28  338409          9             13             0
# ...           ...   ...     ...        ...            ...           ...
# 48837       48837    39  215419          9             13             1
# 48838       48838    64  321403         11              9             1
# 48839       48839    38  374983          9             13             0
# 48840       48840    44   83891          9             13             1
# 48841       48841    35  182148          9             13             0
#
#        relacion  ocupacion  raza  genero  ganancia-capital  perdida-capital  \
# 0             1          0     4       1                 1                0
# 1             0          3     4       1                 0                0
# 2             1          5     4       1                 0                0
# 3             0          5     2       1                 0                0
# 4             5          9     2       0                 0                0
# ...         ...        ...   ...     ...               ...              ...
# 48837         1          9     4       0                 0                0
# 48838         2          9     2       1                 0                0
# 48839         0          9     4       1                 0                0
# 48840         3          0     1       1                 1                0
# 48841         0          3     4       1                 0                0
#
#        horas_semana  pais  tipo_empleo
# 0                40     1            0
# 1                13     1            2
# 2                40     1            1
# 3                40     1            1
# 4                40     0            1
# ...             ...   ...          ...
# 48837            36     1            1
# 48838            40     1            1
# 48839            50     1            1
# 48840            40     1            1
# 48841            60     1            2
#
# [48842 rows x 15 columns]

# %%
y=df['salario']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 48837    1
# 48838    1
# 48839    1
# 48840    1
# 48841    0
# Name: salario, Length: 48842, dtype: int64

# %%
# Dividir los datos en entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
svm_model = SVC(kernel='rbf')  # Puedes cambiar el kernel a 'rbf', 'poly', sigmoid, linear
svm_model.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred = svm_model.predict(x_test)

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.58      0.63      2338
#            1       0.87      0.92      0.89      7431
#
#     accuracy                           0.84      9769
#    macro avg       0.78      0.75      0.76      9769
# weighted avg       0.83      0.84      0.83      9769
#
# Confusion Matrix:
#  [[1362  976]
#  [ 622 6809]]

# %%
# Evalaucion del modelo
print('Train Accuracy : %.5f' % svm_model.score(x_train, y_train))
print('Test Accuracy : %.5f' % svm_model.score(x_test, y_test))
print("Precisión del modelo:", accuracy_score(y_test, y_pred))
# Out:
# Train Accuracy : 0.83690
# Test Accuracy : 0.83642
# Precisión del modelo: 0.8364213327873887

# %%
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index=['0', '1'], columns=['0', '1'])
sns.heatmap(cm_df, annot=True, cmap='Greens', fmt='d', xticklabels=['0', '1'], yticklabels=['0', '1'])
plt.title('Matriz de Confusión')
plt.xlabel('Etiqueta Predicha')
plt.ylabel('Etiqueta Verdadera')
plt.show()

# %%
joblib.dump(svm_model, 'SVModel.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 joblib.dump(model, 'SVModel.pkl')
#
# NameError: name 'model' is not defined
